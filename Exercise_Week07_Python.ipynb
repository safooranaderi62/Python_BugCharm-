# %% [markdown]
# ### Question 00
# import necessary libraries in the box below

# %%
import numpy as np

# %% [markdown]
# ### Question 01
# Create a NumPy array from [1,2,3, ..., 12].

# %%
array_01 = np._( ___ )

# %% [markdown]
# ### Question 02
# Print the type of array array_01

# %%
print(___(array_01))

# %% [markdown]
# ### Question 03
# Reshape array_01 into 3 x 4 matrix.

# %%
array_03 = array_01.___(___)

# %% [markdown]
# ### Question 04
# Get the length of the array_03.

# %%
print(___.___)

# %% [markdown]
# ### Question 05
# Print the second element of the second row in array_03.

# %%
print(array_03[___,___])

# %% [markdown]
# ### Question 06
# Multiply all elements of array_03 by 2.

# %%
array_06 = ___

# %% [markdown]
# ### Question 07
# Add 5 to all elements of array_06.

# %%
print(___)

# %% [markdown]
# ### Question 07
# Create an array of 18 zeros.

# %%
array_07 = np.___(18)

# %% [markdown]
# ### Question 08
# Create an array of 20 fours.

# %%
array_08 = np.___(20) * ___

# %% [markdown]
# ### Question 09
# Create numbers from 0 to 20.

# %%
array_09 = np.___(20)

# %% [markdown]
# ### Question 10
# Create 24 random numbers between 0 and 1.
# Then, Reshape it into matrix with 6 rows.

# %%
array_10 = np.___.___(___)
array_10 = ___.reshape(___)

# %% [markdown]
# ### Question 11
# Convert array_08 to String type.

# %%
array_11 = array_08.astype(___)

# %% [markdown]
# ### Question 12
# Find sum of all rows in array_11

# %%
array_12 = ___
print(array_12.sum(___ = 0))

# %% [markdown]
# ### Question 13
# Find mean of elements of array_10 'in' each row.

# %%
array_14 = ___

print(array_14.___(axis = ___))

# %% [markdown]
# ### Question 14
# Reverse the array_10.

# %%
print(array_10[___])

# %% [markdown]
# ### Question 15
# Add array [1,2,3,4,5,6] to array_10.

# %%
array_15 = np.___([1,2,3,4,5,6])
print(array_10 + ___ )

# %% [markdown]
# ### Question 16
# Print odd column of array_10

# %%
print(array_10[___:___:___])

# %% [markdown]
# ### Question 17
# Create 3x3 zeros matrix.

# %%
array_17 = ___.___((3,3))

# %% [markdown]
# ### Question 18
# Sort the array_10.

# %%
print(___.___(array_10))

# %% [markdown]
# ### Question 19
# Transpose the array_10

# %%
print(___.___)

# %% [markdown]
# ### Question 20
# Create even numbers from 11 to 56.

# %%
array_20 = np.___(11,56,___)
